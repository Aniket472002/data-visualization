# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#numerical data plotting
#relplot has options of plotting both categorical and numerical data
#relplot is relationship plot
#relplot>> how the relationship between two variables
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#how tip is varing with the total bill...>> scatter plot/by default relplot makes scatter plot
sns.relplot(x = 'total_bill', y ='tip', data = df,) #relationship btwn two variable 
plt.show()
#insight >>> total bill increases tip increses

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y ='tip', data = df, hue = 'smoker' ) #relationship btwn two variable 
#insight>> customer goves the highest tip is a smoker...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y ='tip', data = df, hue = 'size' ) #relationship btwn two variable 
#hue---differnt color coding...

# %%
sns.relplot(x = 'total_bill', y ='tip', data = df, style = 'size' ) #relationship btwn two variable 
#style gives the differnt representatio of coloumn values....

# %%
sns.relplot(x = 'total_bill', y ='tip', data = df, hue = 'smoker', style = 'size' ) #relationship btwn two variable

# %%
#relplot for making a line plot 
#line plot >> to understanf the trend in data, a time coloumn /sequence is genrally is there

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()
df =pd.DataFrame({'time' : time, 'value' : value})

# %%
df
# Out:
#      time      value
# 0       0  -0.316709
# 1       1  -0.090205
# 2       2  -1.553941
# 3       3  -1.418370
# 4       4   0.051811
# ..    ...        ...
# 495   495  15.339129
# 496   496  15.569623
# 497   497  15.551716
# 498   498  15.908781
# 499   499  18.635395
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line' , data = df , sort = True)

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True')

# %%
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True', ci = 'sd') #CI IS CONFIDENse INTERVAL

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True', hue = 'event')

# %%
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True', hue = 'event', style = 'region' )

# %%
#removes the dashes in line chart>> 
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True', hue = 'event', style = 'region' , dashes = False)

# %%
sns.relplot(x = 'timepoint' , y = 'signal' , kind = 'line',data = fmri, sort = 'True', hue = 'event', style = 'region', markers = True )

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#making two graphs based on the cloumns >>like lunch and dinner
sns.relplot( x = 'total_bill', y = 'tip', hue = 'smoker' , data = tips, col = 'time')

# %%
sns.relplot( x = 'total_bill', y = 'tip', hue = 'smoker' , data = tips, col = 'size')

# %%
#categorical plots..

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#plot btwn day and total bill .. day is a categorical coloumn or string 
sns.catplot(x = 'day', y ='total_bill' , data = tips)

# %%
#insights many people arrive on sat-sun means on week ends

# %%
#in cat plot, few data points are overlapping >> to see it separately use swarm plot
sns.catplot(x = 'day', y ='total_bill' , data = tips, kind = 'swarm')

# %%
#boxplot>>> to see outliers
sns.catplot(x = 'day', y ='total_bill' , data = tips, kind = 'box')

# %%
sns.catplot(x = 'day', y ='total_bill' , data = tips, kind = 'violin')

# %%
sns.catplot(x = 'day', y ='total_bill' , data = tips, kind = 'boxen') #boxen plot is made from box plot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(y = 'total_bill', x = 'day', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#its draw a plot of two variables with distribution>> bivariate plot
sns.jointplot( x = tips.total_bill, y = tips.tip )

# %%
#joint plot>> understand relationship and also dist of two variable
sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'reg') 
#regression line to represnet relationship

# %%
sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'hex')

# %%
sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'kde')  #kerner density estimator....>>counter plot.....>>uses in metrological departments

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips) #make plots scattter plot with respect to all numnerical coloumns

# %%
sns.pairplot(tips, hue ='smoker', palette = 'coolwarm') #make plots scattter plot with respect to all numnerical coloumns

# %%
sns.pairplot(tips, hue = 'smoker') #make plots scattter plot with respect to all numnerical coloumns

# %%
#box plot  using sns directly
sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 sns.boxplot(data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
df = tips[['total_bill', 'tip', 'size']]
df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df.corr() #>>> gives the correlation of different numerical coloumns like.... if totalbill was increase than tip increases by 67%
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heatmap >>> value encoded with different colours...
sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'sex', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = df, height=  10, aspect=2) #lmplot gives the scatter plot with regression (straight line)
