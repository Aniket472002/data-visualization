# %%
#summarisation of data using visulaization
#matplotlib, seaborn, plotly(most important) ,borekh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') #supress all the warnings

# %%
#line

# %%
#genrate random num in numpy
x = np.random.rand(50)

# %%
x
# Out:
# array([0.36130154, 0.18300941, 0.2205947 , 0.73007834, 0.6878462 ,
#        0.51033988, 0.46415241, 0.60737995, 0.40941935, 0.34185624,
#        0.57735012, 0.09839257, 0.81570091, 0.55099427, 0.35370197,
#        0.31068959, 0.09994395, 0.18508582, 0.57832668, 0.89541359,
#        0.40574028, 0.72432991, 0.04845145, 0.16500657, 0.15420986,
#        0.95690581, 0.83382855, 0.70988636, 0.28613666, 0.35258773,
#        0.11811013, 0.96976252, 0.37192538, 0.58247862, 0.6930764 ,
#        0.96527541, 0.74263376, 0.11239937, 0.44317012, 0.89220379,
#        0.70917493, 0.35473179, 0.8872606 , 0.79401331, 0.45946303,
#        0.17931643, 0.45353819, 0.25320407, 0.44717764, 0.12398394])

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50) #gives normal distribution
# Out:
# array([-0.51911042,  0.51873616,  0.21128037,  1.57140085,  0.61085762,
#        -0.51237715, -0.85727678,  1.07258117, -0.31109174, -0.55014289,
#        -0.59219779, -0.37058323, -0.76839341, -0.64379184, -1.26934184,
#        -0.5422036 ,  0.62054184, -1.37483592,  1.89881195,  0.26021968,
#        -0.85956621, -1.41666592, -0.45880325,  0.68152196, -1.43745041,
#         0.13778172,  0.47202332, -1.67968123, -2.23918696,  0.65713081,
#        -0.45552999,  1.05610166,  0.45966998,  0.49295613, -0.53822014,
#         1.20413045,  0.17523137, -0.70180986,  0.98291577, -0.10042766,
#         2.17001739, -0.33141286, -0.74383215,  0.82632209, -0.3330703 ,
#         0.47200319, -1.81184501, -0.58629677,  1.4192632 ,  1.36184277])

# %%
df =pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11  0.622337
# 2024-07-12  1.092491
# 2024-07-13  0.170549
# 2024-07-14  1.225548
# 2024-07-15  0.396861
# ...              ...
# 2027-04-02  0.007648
# 2027-04-03  0.388535
# 2027-04-04 -0.779080
# 2027-04-05  1.459119
# 2027-04-06 -1.342166
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,8)) #20inch by 8 inch ...>>> most of the value are fluctating betwenn -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.36130154, 0.18300941, 0.2205947 , 0.73007834, 0.6878462 ,
#        0.51033988, 0.46415241, 0.60737995, 0.40941935, 0.34185624,
#        0.57735012, 0.09839257, 0.81570091, 0.55099427, 0.35370197,
#        0.31068959, 0.09994395, 0.18508582, 0.57832668, 0.89541359,
#        0.40574028, 0.72432991, 0.04845145, 0.16500657, 0.15420986,
#        0.95690581, 0.83382855, 0.70988636, 0.28613666, 0.35258773,
#        0.11811013, 0.96976252, 0.37192538, 0.58247862, 0.6930764 ,
#        0.96527541, 0.74263376, 0.11239937, 0.44317012, 0.89220379,
#        0.70917493, 0.35473179, 0.8872606 , 0.79401331, 0.45946303,
#        0.17931643, 0.45353819, 0.25320407, 0.44717764, 0.12398394])

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.7557393 , 0.90439165, 0.99097881, 0.44262513, 0.41391414,
#        0.34204257, 0.34690297, 0.00682536, 0.02130391, 0.08023847,
#        0.71422688, 0.38160192, 0.02886311, 0.20365355, 0.28511911,
#        0.52546222, 0.75757232, 0.81592586, 0.11304694, 0.43726674,
#        0.20657495, 0.62230241, 0.04030393, 0.2351444 , 0.67309446,
#        0.5552971 , 0.46417295, 0.02997716, 0.64849541, 0.52521717,
#        0.79043037, 0.3482034 , 0.75963131, 0.48653846, 0.26996362,
#        0.10765869, 0.77929158, 0.5785192 , 0.68411302, 0.82917341,
#        0.3104463 , 0.94730609, 0.385449  , 0.81988956, 0.66788211,
#        0.51183546, 0.3409005 , 0.12805425, 0.76825688, 0.20694167])

# %%
#scatter plot...>>A Scatter plot is a type of data visualization that displays values of two variable on a cartisiean plane...
plt.scatter(x,y)

# %%
#line plot
#whwnver you want to dipcted the realtion btwn two variable in the form of trend
#mostly in xaxis the dtae -time coloumn is there
x = [1,2,3,4,5] #assume x is no of day
y =[5,2,7,8,1] # y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o",linestyle = "--")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o",linestyle = "--", linewidth = 4)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y, color = "red", marker = "o",linestyle = "--", linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

# %%
plt.plot(x, y1, color = "red", marker= "o", linestyle = "--", linewidth = 3, markersize = 6, label = "line y1 as tata motors")
plt.plot(x, y2, color = "b", marker= "o", linestyle = "--", linewidth = 3, markersize = 6, label = "line y2 as tata power")

plt.title("Multiple lines in one plot")
plt.xlabel("Days")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
 x = np.linspace(0 ,10, 100)

# %%
plt.plot(x , np.sin(x), '--')
plt.plot(x, np.cos(x), '.-')
plt.show()

# %%
#one page two plots
plt.figure()  #initilizing the page yo make plot
plt.subplot(1,2,1)   #one row two coloumns (1,2) it means that...whose names are one and second...
plt.plot(x , np.sin(x))

plt.subplot(1,2,2)
plt.plot(x , np.cos(x))

plt.show()

# %%
#one page two plots
plt.figure()  #initilizing the page yo make plot
plt.subplot(2,1,1)   #one row two coloumns (1,2) it means that...whose names are one and second...
plt.plot(x , np.sin(x))

plt.subplot(2,1,2)
plt.plot(x , np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x , np.sin(x))

plt.subplot(2,2,2)
plt.plot(x , np.cos(x))

plt.subplot(2,2,3)
plt.plot(x , np.tan(x))

plt.subplot(2,2,4)
plt.plot(x , np.sin(x+1))

plt.show()

# %%
plt.plot(x , np.sin(x),color ='b')

# %%
plt.plot(x , np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x , np.sin(x-0),color ='b')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.title("Basic syntax")
plt.xlabel("X")
plt.ylabel("y")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>>continous numerical data.....
data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data, bins=20)
plt.show()

# %%
#stacked historgram>> two histogram together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([ 0.1455392 ,  1.47181572,  1.40121793, ..., -0.67584473,
#         1.01566185, -0.53818665])

# %%
data2
# Out:
# array([1.3414198 , 2.92955359, 4.81266376, ..., 0.9133771 , 2.04790407,
#        3.2822945 ])

# %%
plt.hist([data1, data2], bins=20, color= ['r', 'b'] ,label= ['dist1', 'dist2'])
plt.xlabel("values")
plt.ylabel("frequency")
plt.title("stacked histogram")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.scatter(x,y , c = 'r', marker ="x")

# %%
#bar plot>>> to see the dist of categorical variables
x = ['a', 'b', 'c', 'd']
y = [4,6,1,10]

plt.bar(x,y, color = 'b') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ['a', 'b', 'c', 'd']
y = [4,6,1,10]

plt.barh(x,y, color = 'r') #hprizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#piechart >> to understand the percent dist of data
lans = ['C' , 'Python', 'Java']
students = [20,100,10]

plt.pie(students, labels = lans, autopct = "%1.1f%%") #1.1 means two decimal place and f means frequency...
plt.title("Pie chart")
plt.show()

# %%
#focus on one segment
explode = (0.0, 0.1, 0.1)
lans = ['C' , 'Python', 'Java']
students = [20,100,10]

plt.pie(students, labels = lans, autopct = "%1.1f%%", explode = explode, shadow = True) #1.1 means two decimal place and f means frequency...
plt.title("Pie chart")
plt.show()

# %%
#3d plot
x = np.random.rand(30)
y = np.random.rand(30)
z = np.random.rand(30)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_churn.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x = data["Age"], y= data["Balance"])
plt.show()

# %%
plt.hist(data["Age"])
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Balance"])
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#boxplot >> to check the distribution of data and outliers(extreme/abnormalvalues)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data["Balance"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x22dadc43eb0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x22dadc43e20>,
#  'cmins': <matplotlib.collections.LineCollection at 0x22dadc524c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x22dadc528b0>}

# %%
#area plot>> variable changes over time...

# %%
years = [2021,2018,2022,2023,2017]
category1 = [20,25,30,28,35]
category2 = [10,15,20,18,25]
category3 = [5,8,10,9,15]


plt.stackplot(years, category1,category3,category3, labels = ['category1', 'category2', 'category3'],
              colors = ['skyblue', 'lightgreen', 'orange'])
plt.xlabel("years")
plt.ylabel("values")
plt.title("area plot")
plt.legend()
plt.show()
